# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#!pip install matplotlib
import os
os.getcwd()
# Out:
# 'c:\\Users\\neetu\\Downloads\\DSR\\DSRNotesGit\\week6\\Streamlit18Oct\\StreamlitPractical\\notebooks'

# %%
#os.chdir('./data')

# %%
os.getcwd()

# %%
df = pd.read_csv('../data/global_development_data.csv')
df
# Out:
#        country  year reporting_level welfare_type  ppp_version  survey_year  \
# 0      Albania  1996        national  consumption         2011      1996.00
# 1      Albania  2002        national  consumption         2011      2002.00
# 2      Albania  2005        national  consumption         2011      2005.00
# 3      Albania  2008        national  consumption         2011      2008.00
# 4      Albania  2012        national  consumption         2011      2012.00
# ...        ...   ...             ...          ...          ...          ...
# 3391    Zambia  2004        national  consumption         2017      2004.67
# 3392    Zambia  2006        national  consumption         2017      2006.50
# 3393    Zambia  2010        national  consumption         2017      2010.00
# 3394    Zambia  2015        national  consumption         2017      2015.00
# 3395  Zimbabwe  2011        national  consumption         2017      2011.00
#
#       survey_comparability  headcount_ratio_international_povline  \
# 0                      0.0                               0.920669
# 1                      1.0                               1.570843
# 2                      1.0                               0.860527
# 3                      1.0                               0.313650
# 4                      1.0                               0.849754
# ...                    ...                                    ...
# 3391                   3.0                              61.062458
# 3392                   3.0                              64.698028
# 3393                   4.0                              68.456606
# 3394                   4.0                              61.352160
# 3395                   0.0                              21.580063
#
#       headcount_ratio_lower_mid_income_povline  \
# 0                                    11.174149
# 1                                    14.132118
# 2                                     8.715685
# 3                                     5.250542
# 4                                     6.182414
# ...                                        ...
# 3391                                 78.635262
# 3392                                 81.165271
# 3393                                 82.885088
# 3394                                 77.548045
# 3395                                 47.857143
#
#       headcount_ratio_upper_mid_income_povline  ...  s80_s20_ratio  \
# 0                                    44.618417  ...       3.945872
# 1                                    49.669635  ...       4.831625
# 2                                    38.545254  ...       4.662236
# 3                                    31.110345  ...       4.395911
# 4                                    34.528906  ...       4.272573
# ...                                        ...  ...            ...
# 3391                                 91.888625  ...      16.617988
# 3392                                 92.573347  ...      16.776688
# 3393                                 93.044964  ...      16.024650
# 3394                                 90.747141  ...      21.243915
# 3395                                 77.945113  ...       8.526847
#
#       p90_p10_ratio  p90_p50_ratio  p50_p10_ratio  \
# 0          3.568627       1.889273       1.888889
# 1          3.979381       2.090253       1.903780
# 2          3.872727       1.978328       1.957576
# 3          3.574803       1.956897       1.826772
# 4          3.632877       1.941435       1.871233
# ...             ...            ...            ...
# 3391      11.320755       3.726708       3.037736
# 3392      11.489796       3.829932       3.000000
# 3393      10.470588       3.955556       2.647059
# 3394      13.978261       4.095541       3.413043
# 3395       6.713376       2.773684       2.420382
#
#       Healthy Life Expectancy (IHME)  Life Expectancy (IHME)  \
# 0                              64.87                   74.21
# 1                              65.12                   74.35
# 2                              65.55                   74.77
# 3                              66.03                   75.44
# 4                              67.09                   76.85
# ...                              ...                     ...
# 3391                           39.93                   45.26
# 3392                           41.21                   46.71
# 3393                           45.71                   51.98
# 3394                           50.89                   57.94
# 3395                           45.73                   51.80
#
#       Years Lived With Disability (IHME)  GDP per capita    Population  \
# 0                                   9.34       3965.6853  3.209377e+06
# 1                                   9.23       5608.9623  3.103616e+06
# 2                                   9.21       6858.4670  3.029988e+06
# 3                                   9.42       8522.1298  2.989504e+06
# 4                                   9.75       9592.0000  3.008275e+06
# ...                                  ...             ...           ...
# 3391                                5.34       1828.3099  1.163413e+07
# 3392                                5.50       2133.5939  1.225324e+07
# 3393                                6.27       3032.0679  1.368394e+07
# 3394                                7.06       3478.0000  1.580799e+07
# 3395                                6.07       1515.0000  1.290698e+07
#
#                GDP
# 0     1.272738e+10
# 1     1.740807e+10
# 2     2.078108e+10
# 3     2.547694e+10
# 4     2.885538e+10
# ...            ...
# 3391  2.127079e+10
# 3392  2.614343e+10
# 3393  4.149062e+10
# 3394  5.498018e+10
# 3395  1.955407e+10
#
# [3396 rows x 114 columns]

# %%
print(df.year.min(), df.year.max())
# Out:
# 1990 2016

# %%
# !pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: numpy>=1.22 in c:\users\neetu\anaconda3\envs\streamlit_env\lib\site-packages (from geopandas) (1.26.4)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.10.0-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging in c:\users\neetu\anaconda3\envs\streamlit_env\lib\site-packages (from geopandas) (24.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\neetu\anaconda3\envs\streamlit_env\lib\site-packages (from geopandas) (1.5.3)
# Collecting pyproj>=3.3.0 (from geopandas)
#   Downloading pyproj-3.7.0-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.0.6-cp311-cp311-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\neetu\anaconda3\envs\streamlit_env\lib\site-packages (from pandas>=1.4.0->geopandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\neetu\anaconda3\envs\streamlit_env\lib\site-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: certifi in c:\users\neetu\anaconda3\envs\streamlit_env\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2024.8.30)
# Requirement already satisfied: six>=1.5 in c:\users\neetu\anaconda3\envs\streamlit_env\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.4.0->geopandas) (1.16.0)
# Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
# Downloading pyogrio-0.10.0-cp311-cp311-win_amd64.whl (16.2 MB)
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#    ------------- -------------------------- 5.5/16.2 MB 25.8 MB/s eta 0:00:01
#    ------------------------------- -------- 12.8/16.2 MB 29.8 MB/s eta 0:00:01
#    ------------------------------------- -- 15.2/16.2 MB 23.9 MB/s eta 0:00:01
#    ---------------------------------------- 16.2/16.2 MB 20.8 MB/s eta 0:00:00
# Downloading pyproj-3.7.0-cp311-cp311-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ------------------ --------------------- 2.9/6.2 MB 14.0 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.2 MB 14.8 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 12.7 MB/s eta 0:00:00
# Downloading shapely-2.0.6-cp311-cp311-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 6.9 MB/s eta 0:00:00
# Installing collected packages: shapely, pyproj, pyogrio, geopandas
# Successfully installed geopandas-1.0.1 pyogrio-0.10.0 pyproj-3.7.0 shapely-2.0.6

# %%
import geopandas as gpd
import pandas as pd

# Load your dataset
df = pd.read_csv('../data/global_development_data.csv')

# Load the world shapefile from GeoPandas
world = gpd.read_file(r"..\data\ne_110m_admin_0_countries\ne_110m_admin_0_countries.shp")
# Merge your DataFrame with the world DataFrame based on country names
df_merged = world.merge(df, left_on='NAME', right_on='country', how='inner')
df_merged = df_merged.to_crs(epsg=3857)  # Using Web Mercator for example

# Now you can get the centroid (latitude, longitude) of each country
df_merged['latitude'] = df_merged['geometry'].centroid.y
df_merged['longitude'] = df_merged['geometry'].centroid.x

# Check the updated DataFrame
df_merged[['country', 'latitude', 'longitude','Life Expectancy (IHME)']].head(30)
# Out:
#      country      latitude     longitude  Life Expectancy (IHME)
# 0   Tanzania -7.003071e+05  3.869296e+06                   54.59
# 1   Tanzania -7.003071e+05  3.869296e+06                   52.85
# 2   Tanzania -7.003071e+05  3.869296e+06                   56.98
# 3   Tanzania -7.003071e+05  3.869296e+06                   59.93
# 4   Tanzania -7.003071e+05  3.869296e+06                   54.59
# 5   Tanzania -7.003071e+05  3.869296e+06                   52.85
# 6   Tanzania -7.003071e+05  3.869296e+06                   56.98
# 7   Tanzania -7.003071e+05  3.869296e+06                   59.93
# 8     Canada  1.044422e+07 -1.079779e+07                   77.61
# 9     Canada  1.044422e+07 -1.079779e+07                   77.93
# 10    Canada  1.044422e+07 -1.079779e+07                   78.57
# 11    Canada  1.044422e+07 -1.079779e+07                   78.78
# 12    Canada  1.044422e+07 -1.079779e+07                   79.26
# 13    Canada  1.044422e+07 -1.079779e+07                   80.05
# 14    Canada  1.044422e+07 -1.079779e+07                   80.65
# 15    Canada  1.044422e+07 -1.079779e+07                   81.34
# 16    Canada  1.044422e+07 -1.079779e+07                   81.66
# 17    Canada  1.044422e+07 -1.079779e+07                   81.75
# 18    Canada  1.044422e+07 -1.079779e+07                   81.79
# 19    Canada  1.044422e+07 -1.079779e+07                   81.77
# 20    Canada  1.044422e+07 -1.079779e+07                   81.85
# 21    Canada  1.044422e+07 -1.079779e+07                   77.61
# 22    Canada  1.044422e+07 -1.079779e+07                   77.93
# 23    Canada  1.044422e+07 -1.079779e+07                   78.57
# 24    Canada  1.044422e+07 -1.079779e+07                   78.78
# 25    Canada  1.044422e+07 -1.079779e+07                   79.26
# 26    Canada  1.044422e+07 -1.079779e+07                   80.05
# 27    Canada  1.044422e+07 -1.079779e+07                   80.65
# 28    Canada  1.044422e+07 -1.079779e+07                   81.34
# 29    Canada  1.044422e+07 -1.079779e+07                   81.66

# %%
df_merged.iterrows
# Out:
# <bound method DataFrame.iterrows of            featurecla  scalerank  LABELRANK                   SOVEREIGNT  \
# 0     Admin-0 country          1          3  United Republic of Tanzania
# 1     Admin-0 country          1          3  United Republic of Tanzania
# 2     Admin-0 country          1          3  United Republic of Tanzania
# 3     Admin-0 country          1          3  United Republic of Tanzania
# 4     Admin-0 country          1          3  United Republic of Tanzania
# ...               ...        ...        ...                          ...
# 3213  Admin-0 country          1          6                   Montenegro
# 3214  Admin-0 country          1          6                   Montenegro
# 3215  Admin-0 country          1          6                   Montenegro
# 3216  Admin-0 country          1          5          Trinidad and Tobago
# 3217  Admin-0 country          1          5          Trinidad and Tobago
#
#      SOV_A3  ADM0_DIF  LEVEL               TYPE TLC  \
# 0       TZA         0      2  Sovereign country   1
# 1       TZA         0      2  Sovereign country   1
# 2       TZA         0      2  Sovereign country   1
# 3       TZA         0      2  Sovereign country   1
# 4       TZA         0      2  Sovereign country   1
# ...     ...       ...    ...                ...  ..
# 3213    MNE         0      2  Sovereign country   1
# 3214    MNE         0      2  Sovereign country   1
# 3215    MNE         0      2  Sovereign country   1
# 3216    TTO         0      2  Sovereign country   1
# 3217    TTO         0      2  Sovereign country   1
#
#                             ADMIN  ... p90_p50_ratio  p50_p10_ratio  \
# 0     United Republic of Tanzania  ...      2.300752       2.216667
# 1     United Republic of Tanzania  ...      2.471910       2.170732
# 2     United Republic of Tanzania  ...      2.506250       2.222222
# 3     United Republic of Tanzania  ...      2.429319       1.948980
# 4     United Republic of Tanzania  ...      2.304348       2.236111
# ...                           ...  ...           ...            ...
# 3213                   Montenegro  ...      2.378049       3.207824
# 3214                   Montenegro  ...      2.330317       3.306733
# 3215                   Montenegro  ...      2.245179       3.006211
# 3216          Trinidad and Tobago  ...      2.498728       2.719723
# 3217          Trinidad and Tobago  ...      2.513834       2.705882
#
#      Healthy Life Expectancy (IHME) Life Expectancy (IHME)  \
# 0                             47.67                  54.59
# 1                             46.23                  52.85
# 2                             49.94                  56.98
# 3                             52.64                  59.93
# 4                             47.67                  54.59
# ...                             ...                    ...
# 3213                          66.92                  76.81
# 3214                          67.01                  76.93
# 3215                          67.13                  77.04
# 3216                          60.51                  69.00
# 3217                          60.51                  69.00
#
#       Years Lived With Disability (IHME) GDP per capita    Population  \
# 0                                   6.93       891.8943  2.592461e+07
# 1                                   6.63      1148.6802  3.374130e+07
# 2                                   7.04      1754.4626  4.146135e+07
# 3                                   7.29      2227.0000  4.634354e+07
# 4                                   6.93       891.8943  2.592461e+07
# ...                                  ...            ...           ...
# 3213                                9.88     16437.0000  6.208960e+05
# 3214                                9.92     17249.0000  6.197220e+05
# 3215                                9.91     17741.0000  6.181250e+05
# 3216                                8.49     14195.9518  1.263310e+06
# 3217                                8.49     14195.9518  1.263310e+06
#
#                GDP      latitude     longitude
# 0     2.312201e+10 -7.003071e+05  3.869296e+06
# 1     3.875797e+10 -7.003071e+05  3.869296e+06
# 2     7.274238e+10 -7.003071e+05  3.869296e+06
# 3     1.032071e+11 -7.003071e+05  3.869296e+06
# 4     2.312201e+10 -7.003071e+05  3.869296e+06
# ...            ...           ...           ...
# 3213  1.020567e+10  5.280332e+06  2.146954e+06
# 3214  1.068958e+10  5.280332e+06  2.146954e+06
# 3215  1.096616e+10  5.280332e+06  2.146954e+06
# 3216  1.793388e+10  1.167359e+06 -6.827259e+06
# 3217  1.793388e+10  1.167359e+06 -6.827259e+06
#
# [3218 rows x 285 columns]>
